# %% [markdown]
# ### File Explanation
#
# **trainRNN_ANM_HBTRC_StaticModel.ipynb:**
# <br> This notebook is to load AddNeuroMed examples from 'preprocessData.pickle', and HBTRC examples from 'preprocessData_HBTRC.pickle' and create a "Static Network". Train the network on AddNeuroMed data set and test on HBTRC data set
#
# **Variables information**:
# <br> 1) Variables in the format of xxx_A represents data from AddNeuroMed
# <br> 2) Variables in the format of xxx_H represents data from HBTRC
#
# **Processes are as follows:**
# <br> 1) Load all variables from 'preprocessData.pickle' and 'preprocessData_HBTRC'
# <br> 2) Parameter and hyperparameter assignments (location: **3rd cell**)
# <br> 3) Create LSTM cells with Dropout Wrappers for gene A and gene B (function: **dropoutWrapper** in **trainRNN_network_utils.py**)
# <br> 4) Using LSTM cells, create multi-layer static model (function: **LSTM_Model** in **trainRNN_network_utils.py**)
# <br> 5) Create a single normalised output by using the last outputs of static models of gene A and gene B (function: **batch_normalised_sum** in **trainRNN_network_utils.py**)
# <br> 6) Pass the output through a **dense** layer and make prediction with **softmax**
# <br> 7) Before starting the training: concatenate rSnpG_tr_nXSN and rRnaG_nXS where G represents gene A and gene B (function: **input_reshape** in **trainRNN_utils.py**)
# <br> 7) Train the network: every epoch (i.e., iteration) shuffle the data within each class (function: **shuffle_classes** in **trainRNN_utils.py**) and train in batches (function: **extract_batch_size** in **trainRNN_utils.py**)
# <br> 8) Plot results with **plot_one_input** in **trainRNN_plot_utils.py**)
# <br> 9) Save them in "resultsStatic_ANM_HBTRC.pickle" to be called when necessary
#
# **Variables created:**
# <br> 1) **trainLosses**: Train losses, dictionary, keys of (dropout)
# <br> 2) **testLosses**: Test losses, dictionary, keys of (dropout)
# <br> 3) **F1_scores**: F1_scores, dictionary, keys of (dropout)
# <br> 4) **trainAccuracy**: Train accuracy, dictionary, keys of (dropout)

# %%
import tensorflow as tf
from IPython.core.debugger import set_trace #set_trace()
import numpy as np
import sys
import pandas as pd
from tensorflow.contrib import rnn
import matplotlib.pyplot as plt

import os
os.environ[ "CUDA_VISIBLE_DEVICES" ] = "3"

# %matplotlib inline

# %%
# LOAD AddNeuroMed DATA
# Load data form the pickle produced by "preprocessData_TT_v3.ipynb" in AddNeuroMed folder

# Save data into Python friendly file
import pickle
with open('../AddNeuroMed/preprocessData.pickle', 'rb') as f:
    rSnpA_nXSN_A = pickle.load( f )
    rSnpB_nXSN_A = pickle.load( f )
    rRnaA_nXS_A = pickle.load( f )
    rRnaB_nXS_A = pickle.load( f )
    rRelated_nXC_A = pickle.load( f )
    rSnpA_tr_nXSN_A = pickle.load( f )
    rSnpB_tr_nXSN_A = pickle.load( f )
    rRnaA_tr_nXS_A = pickle.load( f )
    rRnaB_tr_nXS_A = pickle.load( f )
    rRelated_tr_nXC_A = pickle.load( f )
    rSnpA_tst_nXSN_A = pickle.load( f )
    rSnpB_tst_nXSN_A = pickle.load( f )
    rRnaA_tst_nXS_A = pickle.load( f )
    rRnaB_tst_nXS_A = pickle.load( f )
    rRelated_tst_nXC_A = pickle.load( f )
    sGeneNames_nX2_A = pickle.load( f )
    nRs_A = pickle.load( f )
    nSs_A = pickle.load( f )
    print( 'AddNeuroMed data loaded from pickle.' )


# Check the input dimensions
assert( len( rSnpA_nXSN_A.shape ) == 3 )
assert( len( rSnpB_nXSN_A.shape ) == 3 )
assert( len( rRnaA_nXS_A.shape ) == 2 )
assert( len( rRnaB_nXS_A.shape ) == 2)
assert( len( rRelated_nXC_A.shape ) == 2 )
assert( len( rSnpA_tr_nXSN_A.shape ) == 3 )
assert( len( rSnpB_tr_nXSN_A.shape ) == 3 )
assert( len( rRnaA_tr_nXS_A.shape ) == 2 )
assert( len( rRnaB_tr_nXS_A.shape ) == 2 )
assert( len( rRelated_tr_nXC_A.shape ) == 2 )
assert( len( rSnpA_tst_nXSN_A.shape ) == 3 )
assert( len( rSnpB_tst_nXSN_A.shape ) == 3 )
assert( len( rRnaA_tst_nXS_A.shape ) == 2 )
assert( len( rRnaB_tst_nXS_A.shape ) == 2 )
assert( len( rRelated_tst_nXC_A.shape ) == 2)
assert( rSnpA_nXSN_A.shape[ 0 ] == rRnaA_nXS_A.shape[0] )
assert( rSnpA_nXSN_A.shape[ 0 ] == rRnaB_nXS_A.shape[0] )
assert( rSnpB_nXSN_A.shape[ 0 ] == rRnaA_nXS_A.shape[0] )
assert( rSnpB_nXSN_A.shape[ 0 ] == rRnaB_nXS_A.shape[0] )
assert( rSnpA_nXSN_A.shape[ 0 ] == rRelated_nXC_A.shape[ 0 ] )
assert( rSnpA_nXSN_A.shape[ 1 ] == rRnaA_nXS_A.shape[ 1 ] )
assert( rSnpB_nXSN_A.shape[ 1 ] == rRnaB_nXS_A.shape[ 1 ] )
assert( rRelated_nXC_A.shape[ 1 ] == 3 )

iSnum_A = rSnpA_nXSN_A.shape[ 1 ] # Number of subjects
iNnum_A = rSnpA_nXSN_A.shape[ 2 ] # Number of snps
iCnum_A = rRelated_nXC_A.shape[ 1 ] # Number of classes

print('All AddNeuroMed samples loaded.' )
print('Number of training samples (transcripts) of gene A: {}'.format( rSnpA_tr_nXSN_A.shape[ 0 ] ) )
print('Number of training samples (transcripts) of gene B: {}'.format( rSnpB_tr_nXSN_A.shape[ 0 ] ) )
print('Number of test samples (transcripts) of gene A: {}'.format( rSnpA_tst_nXSN_A.shape[ 0 ] ) )
print('Number of test samples (transcripts) of gene B: {}'.format( rSnpB_tst_nXSN_A.shape[ 0 ] ) )
print('Number of subjects iSnum: {}'.format( rSnpA_nXSN_A.shape[ 1 ] ) )
print('Number of SNPs iNnum: {}'.format( rSnpA_nXSN_A.shape[ 2 ] ) )
print('Number of association classes iCnum: {}'.format( rRelated_nXC_A.shape[ 1 ] ) )
# Out:
# AddNeuroMed data loaded from pickle.
# All AddNeuroMed samples loaded.
# Number of training samples (transcripts) of gene A: 1500
# Number of training samples (transcripts) of gene B: 1500
# Number of test samples (transcripts) of gene A: 45
# Number of test samples (transcripts) of gene B: 45
# Number of subjects iSnum: 206
# Number of SNPs iNnum: 100
# Number of association classes iCnum: 3

# %%
# LOAD HBTRC DATA
# Load data form the pickle produced by "preprocessData_HBTRC_v4.ipynb"

# Save data into Python friendly file
import pickle
with open('../HBTRC/preprocessData_HBTRC.pickle', 'rb') as f:
    rSnpA_nXSN_H = pickle.load( f )
    rSnpB_nXSN_H = pickle.load( f )
    rRnaA_nXS_H = pickle.load( f )
    rRnaB_nXS_H = pickle.load( f )
    rRelated_nXC_H = pickle.load( f )
    rSnpA_tr_nXSN_H = pickle.load( f )
    rSnpB_tr_nXSN_H = pickle.load( f )
    rRnaA_tr_nXS_H = pickle.load( f )
    rRnaB_tr_nXS_H = pickle.load( f )
    rRelated_tr_nXC_H = pickle.load( f )
    rSnpA_tst_nXSN_H = pickle.load( f )
    rSnpB_tst_nXSN_H = pickle.load( f )
    rRnaA_tst_nXS_H = pickle.load( f )
    rRnaB_tst_nXS_H = pickle.load( f )
    rRelated_tst_nXC_H = pickle.load( f )
    sGeneNames_nX2_H = pickle.load( f )
    nRs_H = pickle.load( f )
    nSs_H = pickle.load( f )
    print( 'HBTRC loaded from pickle.' )


# Check the input dimensions
assert( len( rSnpA_nXSN_H.shape ) == 3 )
assert( len( rSnpB_nXSN_H.shape ) == 3 )
assert( len( rRnaA_nXS_H.shape ) == 2 )
assert( len( rRnaB_nXS_H.shape ) == 2)
assert( len( rRelated_nXC_H.shape ) == 2 )
assert( len( rSnpA_tr_nXSN_H.shape ) == 3 )
assert( len( rSnpB_tr_nXSN_H.shape ) == 3 )
assert( len( rRnaA_tr_nXS_H.shape ) == 2 )
assert( len( rRnaB_tr_nXS_H.shape ) == 2 )
assert( len( rRelated_tr_nXC_H.shape ) == 2 )
assert( len( rSnpA_tst_nXSN_H.shape ) == 3 )
assert( len( rSnpB_tst_nXSN_H.shape ) == 3 )
assert( len( rRnaA_tst_nXS_H.shape ) == 2 )
assert( len( rRnaB_tst_nXS_H.shape ) == 2 )
assert( len( rRelated_tst_nXC_H.shape ) == 2)
assert( rSnpA_nXSN_H.shape[ 0 ] == rRnaA_nXS_H.shape[0] )
assert( rSnpA_nXSN_H.shape[ 0 ] == rRnaB_nXS_H.shape[0] )
assert( rSnpB_nXSN_H.shape[ 0 ] == rRnaA_nXS_H.shape[0] )
assert( rSnpB_nXSN_H.shape[ 0 ] == rRnaB_nXS_H.shape[0] )
assert( rSnpA_nXSN_H.shape[ 0 ] == rRelated_nXC_H.shape[ 0 ] )
assert( rSnpA_nXSN_H.shape[ 1 ] == rRnaA_nXS_H.shape[ 1 ] )
assert( rSnpB_nXSN_H.shape[ 1 ] == rRnaB_nXS_H.shape[ 1 ] )
assert( rRelated_nXC_H.shape[ 1 ] == 3 )

iSnum_H = rSnpA_nXSN_H.shape[ 1 ] # Number of subjects
iNnum_H = rSnpA_nXSN_H.shape[ 2 ] # Number of snps
iCnum_H = rRelated_nXC_H.shape[ 1 ] # Number of classes

print('All HBTRC samples loaded.' )
print('Number of training samples (transcripts) of gene A: {}'.format( rSnpA_tr_nXSN_H.shape[ 0 ] ) )
print('Number of training samples (transcripts) of gene B: {}'.format( rSnpB_tr_nXSN_H.shape[ 0 ] ) )
print('Number of test samples (transcripts) of gene A: {}'.format( rSnpA_tst_nXSN_H.shape[ 0 ] ) )
print('Number of test samples (transcripts) of gene B: {}'.format( rSnpB_tst_nXSN_H.shape[ 0 ] ) )
print('Number of subjects iSnum: {}'.format( rSnpA_nXSN_H.shape[ 1 ] ) )
print('Number of SNPs iNnum: {}'.format( rSnpA_nXSN_H.shape[ 2 ] ) )
print('Number of association classes iCnum: {}'.format( rRelated_nXC_H.shape[ 1 ] ) )
# Out:
# HBTRC loaded from pickle.
# All HBTRC samples loaded.
# Number of training samples (transcripts) of gene A: 1500
# Number of training samples (transcripts) of gene B: 1500
# Number of test samples (transcripts) of gene A: 45
# Number of test samples (transcripts) of gene B: 45
# Number of subjects iSnum: 434
# Number of SNPs iNnum: 100
# Number of association classes iCnum: 3

# %% [markdown]
# ### Parameters

# %%
# Parameters

## Input data
time_steps = iNnum_A + 1                            # number of snps + number of rnas
n_input = iSnum_A                                   # number of subjects

## LSTM's internal structure
n_hidden = 32                                       # number of nodes in hidden layer 
n_classes = iCnum_A                                 # number of classes
n_layer = 3                                         # number of layers
dropout = 0.6                                       # dropout percentage

## Training data
learning_rate = 0.001
batch_size = 150
n_epoch = 250
n_batch = rSnpA_tr_nXSN_A.shape[0] // batch_size # number of batches

# %% [markdown]
# ### Network and Train

# %%
# %run trainRNN_utils.py
# %run trainRNN_network_utils.py

trainLosses = {}
testLosses = {}
F1_scores = {}
trainAccuracy = {}

# Create network
tf.reset_default_graph()

# Gene A and Gene B input and output placeholders
## Input placeholders
with tf.variable_scope('geneA'):

    rSnpRnaA_pXNS = tf.placeholder(tf.float32, shape = [None, iNnum_A + 1, iSnum_A])
    init_state_A = tf.placeholder(tf.float32, [n_layer, 2, None, n_hidden])

    hidden_output_A, current_state_A = LSTM_Model(rSnpRnaA_pXNS, 
                                                      init_state_A, 
                                                      n_layer, 
                                                      n_hidden, 
                                                      dropout)

with tf.variable_scope('geneB'):

    rSnpRnaB_pXNS = tf.placeholder(tf.float32, shape = [None, iNnum_A + 1, iSnum_A])
    init_state_B = tf.placeholder(tf.float32, [n_layer, 2, None, n_hidden])

    hidden_output_B, current_state_B = LSTM_Model(rSnpRnaB_pXNS, 
                                                      init_state_A, 
                                                      n_layer, 
                                                      n_hidden, 
                                                      dropout)

hidden_output = batch_normalised_sum(hidden_output_A, hidden_output_B)

## Output placeholder
rRelated_pXC = tf.placeholder(tf.float32, 
                              shape = [None, iCnum_A],
                              name = 'rRelated_pXC')

# Dense Layer
logit = tf.layers.dense( hidden_output,
                        units = n_classes, 
                        activation = None,
                        kernel_initializer = tf.initializers.random_normal() ) 

prediction = tf.nn.softmax( logit )

## Loss and optimiser
cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=prediction, 
                                                                     labels=tf.argmax(rRelated_pXC,1)))

optimiser = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Accuracy; precision, and recall for f1 score
correct_pred = tf.equal(tf.argmax(prediction,1), tf.argmax(rRelated_pXC,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

rec, rec_op = tf.metrics.recall(labels = tf.argmax(rRelated_pXC, 1), predictions = tf.argmax(prediction, 1))
pre, pre_op = tf.metrics.precision(labels = tf.argmax(rRelated_pXC, 1), predictions = tf.argmax(prediction, 1))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())

    # Train the network 
    train_losses = []
    train_accuracies = []
    train_f1_score = [None] * n_epoch
    test_losses = []
    test_accuracies = []
    test_f1_score = []

    # Reshape rSnpRnaA_tst_nXSN_H, rRnaA_tst_nXS_H,  rSnpRnaB_tst_nXSN_H, and rRnaB_tst_nXS_H before 
    # feeding it to the network ( Reason: iSnum_A = 206, iSnum_H = 434). For HBTRC data, randomly select 206
    # subjects to align iSnum.
    rand_iSnum = np.random.permutation(iSnum_H)[0:206] 
    rSnpA_tst_nXSN_H_2 = rSnpA_tst_nXSN_H[:, rand_iSnum, :]
    rRnaA_tst_nXS_H_2 = rRnaA_tst_nXS_H[:, rand_iSnum]
    rSnpB_tst_nXSN_H_2 = rSnpB_tst_nXSN_H[:, rand_iSnum, :]
    rRnaB_tst_nXS_H_2 = rRnaB_tst_nXS_H[:, rand_iSnum]

    # Reshape and retrive the merged training and test data
    rSnpRnaA_tr_nXNS = input_reshape(rSnpA_tr_nXSN_A, rRnaA_tr_nXS_A)
    rSnpRnaB_tr_nXNS = input_reshape(rSnpB_tr_nXSN_A, rRnaB_tr_nXS_A)
    rSnpRnaA_tst_nXNS = input_reshape(rSnpA_tst_nXSN_H_2, rRnaA_tst_nXS_H_2)
    rSnpRnaB_tst_nXNS = input_reshape(rSnpB_tst_nXSN_H_2, rRnaB_tst_nXS_H_2)
    
    # Initial current_state
    _current_state_A = np.zeros((n_layer, 2, batch_size, n_hidden))
    _current_state_B = np.zeros((n_layer, 2, batch_size, n_hidden))
    _current_state_tst_A = np.zeros((n_layer, 2, rSnpA_tst_nXSN_H.shape[0], n_hidden))
    _current_state_tst_B = np.zeros((n_layer, 2, rSnpA_tst_nXSN_H.shape[0], n_hidden))

    for epoch_idx in range(n_epoch): 


        print("Data shuffled." + \
              " Epoch: ", epoch_idx)

        # Shuffle classes
        rSnpRnaA_tr_nXNS, rSnpRnaB_tr_nXNS = shuffle_classes(rSnpRnaA_tr_nXNS, rSnpRnaB_tr_nXNS)

        for batch_idx in range(n_batch):

            batch_rSnpRnaA_tXNS = extract_batch_size(rSnpRnaA_tr_nXNS, batch_idx, batch_size)
            batch_rSnpRnaB_tXNS = extract_batch_size(rSnpRnaB_tr_nXNS, batch_idx, batch_size)
            batch_rRelated_tXC = extract_batch_size(rRelated_tr_nXC_A, batch_idx, batch_size)

            # Fit training data
            opt, tr_loss, tr_acc = sess.run(
                [optimiser, cost, accuracy], 
                feed_dict = {
                    rSnpRnaA_pXNS: batch_rSnpRnaA_tXNS,
                    rSnpRnaB_pXNS: batch_rSnpRnaB_tXNS,
                    rRelated_pXC: batch_rRelated_tXC,
                    init_state_A: _current_state_A,                      
                    init_state_B: _current_state_B, 
                })

            tst_loss, tst_pre, _, tst_rec, _ = sess.run(
                [cost, pre, pre_op, rec, rec_op],
                feed_dict = {
                    rSnpRnaA_pXNS: rSnpRnaA_tst_nXNS,
                    rSnpRnaB_pXNS: rSnpRnaB_tst_nXNS,
                    rRelated_pXC: rRelated_tst_nXC_H,
                    init_state_A: _current_state_tst_A,                      
                    init_state_B: _current_state_tst_B,
                    })            

            if batch_idx == (n_batch - 1):

                train_losses.append(tr_loss)
                train_accuracies.append(tr_acc)

                tst_f1_score = 2 * ( tst_rec * tst_pre ) / (tst_rec + tst_pre) 

                test_losses.append(tst_loss)
                test_f1_score.append(tst_f1_score)

        print("Performance on training data" + 
             ": Loss = {}".format(tr_loss) + 
             ": Accuracy = {}".format( tr_acc ) )

        print("Performance on test set: " + 
              ": Loss = {}".format(tst_loss) + 
              ": Accuracy = {}".format(tst_f1_score) )
        print("")

    trainLosses[dropout] = train_losses
    testLosses[dropout] = test_losses
    F1_scores[dropout] = test_f1_score
print("Optimisation finished!")
# Out:
# Data shuffled. Epoch:  0
# Performance on training data: Loss = 1.0836107730865479: Accuracy = 0.40666666626930237
# Performance on test set: : Loss = 1.1191728115081787: Accuracy = 0.7828746804972195
#
# Data shuffled. Epoch:  1
# Performance on training data: Loss = 1.0766993761062622: Accuracy = 0.3933333456516266
# Performance on test set: : Loss = 1.1051944494247437: Accuracy = 0.7348193180839744
#
# Data shuffled. Epoch:  2
# Performance on training data: Loss = 1.0615750551223755: Accuracy = 0.4333333373069763
# Performance on test set: : Loss = 1.128530740737915: Accuracy = 0.7431147314944851
#
# Data shuffled. Epoch:  3
# Performance on training data: Loss = 1.1100584268569946: Accuracy = 0.3799999952316284
# Performance on test set: : Loss = 1.1089686155319214: Accuracy = 0.7231594651742835
#
# Data shuffled. Epoch:  4
# Performance on training data: Loss = 1.0247043371200562: Accuracy = 0.46000000834465027
# Performance on test set: : Loss = 1.0978717803955078: Accuracy = 0.718060287856065
#
# Data shuffled. Epoch:  5
# Performance on training data: Loss = 1.076384425163269: Accuracy = 0.35333332419395447
# Performance on test set: : Loss = 1.1017085313796997: Accuracy = 0.7034300857669081
#
# Data shuffled. Epoch:  6
# Performance on training data: Loss = 1.090868353843689: Accuracy = 0.3733333349227905
# Performance on test set: : Loss = 1.1159381866455078: Accuracy = 0.6850777281381142
#
# Data shuffled. Epoch:  7
# Performance on training data: Loss = 1.0552998781204224: Accuracy = 0.41999998688697815
# Performance on test set: : Loss = 1.1206761598587036: Accuracy = 0.6774856679853838
#
# Data shuffled. Epoch:  8
# Performance on training data: Loss = 1.066108226776123: Accuracy = 0.4333333373069763
# Performance on test set: : Loss = 1.1244852542877197: Accuracy = 0.6711876693905858
#
# Data shuffled. Epoch:  9
# Performance on training data: Loss = 1.0697898864746094: Accuracy = 0.3733333349227905
# Performance on test set: : Loss = 1.1031683683395386: Accuracy = 0.6591898553020472
#
# Data shuffled. Epoch:  10
# Performance on training data: Loss = 1.1004787683486938: Accuracy = 0.3466666638851166
# Performance on test set: : Loss = 1.1321601867675781: Accuracy = 0.6634396955934788
#
# Data shuffled. Epoch:  11
# Performance on training data: Loss = 1.0466773509979248: Accuracy = 0.4000000059604645
# Performance on test set: : Loss = 1.1027668714523315: Accuracy = 0.6696820472472047
#
# Data shuffled. Epoch:  12
# Performance on training data: Loss = 1.0454514026641846: Accuracy = 0.4399999976158142
# Performance on test set: : Loss = 1.151912808418274: Accuracy = 0.671383458329037
#
# Data shuffled. Epoch:  13
# Performance on training data: Loss = 1.0285722017288208: Accuracy = 0.4533333480358124
# Performance on test set: : Loss = 1.0927460193634033: Accuracy = 0.6658822800934749
#
# Data shuffled. Epoch:  14
# Performance on training data: Loss = 1.0597851276397705: Accuracy = 0.4000000059604645
# Performance on test set: : Loss = 1.1022447347640991: Accuracy = 0.6638035269390503
#
# Data shuffled. Epoch:  15
# Performance on training data: Loss = 1.0276013612747192: Accuracy = 0.47999998927116394
# Performance on test set: : Loss = 1.1283870935440063: Accuracy = 0.6639149205437402
#
# Data shuffled. Epoch:  16
# Performance on training data: Loss = 1.0197230577468872: Accuracy = 0.4866666793823242
# Performance on test set: : Loss = 1.1261231899261475: Accuracy = 0.6634307712759269
#
# Data shuffled. Epoch:  17
# Performance on training data: Loss = 1.0684200525283813: Accuracy = 0.36666667461395264
# Performance on test set: : Loss = 1.091483235359192: Accuracy = 0.6570530421819698
#
# Data shuffled. Epoch:  18
# Performance on training data: Loss = 1.0535097122192383: Accuracy = 0.4000000059604645
# Performance on test set: : Loss = 1.0780549049377441: Accuracy = 0.660845255011542
#
# Data shuffled. Epoch:  19
# Performance on training data: Loss = 1.037814736366272: Accuracy = 0.4533333480358124
# Performance on test set: : Loss = 1.1114591360092163: Accuracy = 0.6628600217001105
#
# Data shuffled. Epoch:  20
# Performance on training data: Loss = 1.0689473152160645: Accuracy = 0.3799999952316284
# Performance on test set: : Loss = 1.1425809860229492: Accuracy = 0.6572382366773818
#
# Data shuffled. Epoch:  21
# Performance on training data: Loss = 1.0295829772949219: Accuracy = 0.4866666793823242
# Performance on test set: : Loss = 1.104335904121399: Accuracy = 0.6523802301864469
#
# Data shuffled. Epoch:  22
# Performance on training data: Loss = 1.0368820428848267: Accuracy = 0.4266666769981384
# Performance on test set: : Loss = 1.07948637008667: Accuracy = 0.6566554829185289
#
# Data shuffled. Epoch:  23
# Performance on training data: Loss = 1.0649861097335815: Accuracy = 0.4333333373069763
# Performance on test set: : Loss = 1.0871151685714722: Accuracy = 0.6589595556104703
#
# Data shuffled. Epoch:  24
# Performance on training data: Loss = 1.0492732524871826: Accuracy = 0.4266666769981384
# Performance on test set: : Loss = 1.0882346630096436: Accuracy = 0.6603849162535068
#
# Data shuffled. Epoch:  25
# Performance on training data: Loss = 1.047148585319519: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.118398666381836: Accuracy = 0.6608740535734111
#
# Data shuffled. Epoch:  26
# Performance on training data: Loss = 1.04116690158844: Accuracy = 0.46666666865348816
# Performance on test set: : Loss = 1.0878256559371948: Accuracy = 0.6596682583886162
#
# Data shuffled. Epoch:  27
# Performance on training data: Loss = 1.0230882167816162: Accuracy = 0.4933333396911621
# Performance on test set: : Loss = 1.1097676753997803: Accuracy = 0.6628891507249677
#
# Data shuffled. Epoch:  28
# Performance on training data: Loss = 1.040211796760559: Accuracy = 0.4399999976158142
# Performance on test set: : Loss = 1.1003024578094482: Accuracy = 0.6672392897026826
#
# Data shuffled. Epoch:  29
# Performance on training data: Loss = 1.0351808071136475: Accuracy = 0.4533333480358124
# Performance on test set: : Loss = 1.1346111297607422: Accuracy = 0.6694251466288257
#
# Data shuffled. Epoch:  30
# Performance on training data: Loss = 1.0548474788665771: Accuracy = 0.4333333373069763
# Performance on test set: : Loss = 1.1249552965164185: Accuracy = 0.6703290748452966
#
# Data shuffled. Epoch:  31
# Performance on training data: Loss = 1.0575507879257202: Accuracy = 0.3799999952316284
# Performance on test set: : Loss = 1.127207636833191: Accuracy = 0.6704915082038031
#
# Data shuffled. Epoch:  32
# Performance on training data: Loss = 1.0599925518035889: Accuracy = 0.3866666555404663
# Performance on test set: : Loss = 1.1213468313217163: Accuracy = 0.6695770530594283
#
# Data shuffled. Epoch:  33
# Performance on training data: Loss = 1.045109748840332: Accuracy = 0.41999998688697815
# Performance on test set: : Loss = 1.1062426567077637: Accuracy = 0.6693631057750107
#
# Data shuffled. Epoch:  34
# Performance on training data: Loss = 1.023833990097046: Accuracy = 0.4466666579246521
# Performance on test set: : Loss = 1.1166000366210938: Accuracy = 0.6683734266925331
#
# Data shuffled. Epoch:  35
# Performance on training data: Loss = 1.0261330604553223: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.140034556388855: Accuracy = 0.6690293098230681
#
# Data shuffled. Epoch:  36
# Performance on training data: Loss = 1.0383501052856445: Accuracy = 0.4466666579246521
# Performance on test set: : Loss = 1.1170287132263184: Accuracy = 0.671248786098962
#
# Data shuffled. Epoch:  37
# Performance on training data: Loss = 1.0587416887283325: Accuracy = 0.4466666579246521
# Performance on test set: : Loss = 1.1276836395263672: Accuracy = 0.6732028944119635
#
# Data shuffled. Epoch:  38
# Performance on training data: Loss = 1.0127217769622803: Accuracy = 0.5
# Performance on test set: : Loss = 1.071643590927124: Accuracy = 0.673315863102735
#
# Data shuffled. Epoch:  39
# Performance on training data: Loss = 1.013081431388855: Accuracy = 0.46666666865348816
# Performance on test set: : Loss = 1.1240739822387695: Accuracy = 0.6738037868732294
#
# Data shuffled. Epoch:  40
# Performance on training data: Loss = 1.0629308223724365: Accuracy = 0.3799999952316284
# Performance on test set: : Loss = 1.1376631259918213: Accuracy = 0.6749258673471821
#
# Data shuffled. Epoch:  41
# Performance on training data: Loss = 1.0316331386566162: Accuracy = 0.4533333480358124
# Performance on test set: : Loss = 1.1307926177978516: Accuracy = 0.6744459348825604
#
# Data shuffled. Epoch:  42
# Performance on training data: Loss = 1.0540872812271118: Accuracy = 0.41999998688697815
# Performance on test set: : Loss = 1.118595838546753: Accuracy = 0.6744951100610637
#
# Data shuffled. Epoch:  43
# Performance on training data: Loss = 1.0352582931518555: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.1253268718719482: Accuracy = 0.6731575843748775
#
# Data shuffled. Epoch:  44
# Performance on training data: Loss = 1.0247806310653687: Accuracy = 0.46666666865348816
# Performance on test set: : Loss = 1.128570556640625: Accuracy = 0.6721419298298813
#
# Data shuffled. Epoch:  45
# Performance on training data: Loss = 1.0103360414505005: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.1217925548553467: Accuracy = 0.6695463862978375
#
# Data shuffled. Epoch:  46
# Performance on training data: Loss = 0.9943453073501587: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.1110926866531372: Accuracy = 0.6681492175462256
#
# Data shuffled. Epoch:  47
# Performance on training data: Loss = 0.9646034836769104: Accuracy = 0.5400000214576721
# Performance on test set: : Loss = 1.1019442081451416: Accuracy = 0.6691054856770675
#
# Data shuffled. Epoch:  48
# Performance on training data: Loss = 1.0310534238815308: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.1087361574172974: Accuracy = 0.6697972833908203
#
# Data shuffled. Epoch:  49
# Performance on training data: Loss = 0.9787060618400574: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.1198039054870605: Accuracy = 0.667640970877288
#
# Data shuffled. Epoch:  50
# Performance on training data: Loss = 0.9710124731063843: Accuracy = 0.5133333206176758
# Performance on test set: : Loss = 1.1168214082717896: Accuracy = 0.6665145386510384
#
# Data shuffled. Epoch:  51
# Performance on training data: Loss = 1.0179557800292969: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.11433744430542: Accuracy = 0.6667519782422406
#
# Data shuffled. Epoch:  52
# Performance on training data: Loss = 0.961466372013092: Accuracy = 0.54666668176651
# Performance on test set: : Loss = 1.1461520195007324: Accuracy = 0.6657242745024798
#
# Data shuffled. Epoch:  53
# Performance on training data: Loss = 0.9560588598251343: Accuracy = 0.5733333230018616
# Performance on test set: : Loss = 1.106666922569275: Accuracy = 0.6650614227933368
#
# Data shuffled. Epoch:  54
# Performance on training data: Loss = 0.9709946513175964: Accuracy = 0.5266666412353516
# Performance on test set: : Loss = 1.0877679586410522: Accuracy = 0.6652528470220236
#
# Data shuffled. Epoch:  55
# Performance on training data: Loss = 0.9621321558952332: Accuracy = 0.5333333611488342
# Performance on test set: : Loss = 1.0913416147232056: Accuracy = 0.6650793307961292
#
# Data shuffled. Epoch:  56
# Performance on training data: Loss = 0.9568257927894592: Accuracy = 0.5333333611488342
# Performance on test set: : Loss = 1.0907524824142456: Accuracy = 0.6638355376952715
#
# Data shuffled. Epoch:  57
# Performance on training data: Loss = 0.9967160820960999: Accuracy = 0.5133333206176758
# Performance on test set: : Loss = 1.105426549911499: Accuracy = 0.6643638589593418
#
# Data shuffled. Epoch:  58
# Performance on training data: Loss = 0.9502641558647156: Accuracy = 0.54666668176651
# Performance on test set: : Loss = 1.0871343612670898: Accuracy = 0.6664031708227636
#
# Data shuffled. Epoch:  59
# Performance on training data: Loss = 0.9895970821380615: Accuracy = 0.4933333396911621
# Performance on test set: : Loss = 1.1239681243896484: Accuracy = 0.6646983894976596
#
# Data shuffled. Epoch:  60
# Performance on training data: Loss = 0.9712589383125305: Accuracy = 0.5133333206176758
# Performance on test set: : Loss = 1.098364233970642: Accuracy = 0.6642365837094977
#
# Data shuffled. Epoch:  61
# Performance on training data: Loss = 0.9531516432762146: Accuracy = 0.5666666626930237
# Performance on test set: : Loss = 1.1212576627731323: Accuracy = 0.6632636500418815
#
# Data shuffled. Epoch:  62
# Performance on training data: Loss = 0.9677504301071167: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.0797759294509888: Accuracy = 0.6622071968119136
#
# Data shuffled. Epoch:  63
# Performance on training data: Loss = 0.9586217999458313: Accuracy = 0.5533333420753479
# Performance on test set: : Loss = 1.1763060092926025: Accuracy = 0.6610988058707897
#
# Data shuffled. Epoch:  64
# Performance on training data: Loss = 0.9770749807357788: Accuracy = 0.4933333396911621
# Performance on test set: : Loss = 1.1451473236083984: Accuracy = 0.6583007068505429
#
# Data shuffled. Epoch:  65
# Performance on training data: Loss = 0.9421029686927795: Accuracy = 0.5799999833106995
# Performance on test set: : Loss = 1.0827285051345825: Accuracy = 0.6590839172651878
#
# Data shuffled. Epoch:  66
# Performance on training data: Loss = 0.9734941720962524: Accuracy = 0.54666668176651
# Performance on test set: : Loss = 1.1271671056747437: Accuracy = 0.6569607743437753
#
# Data shuffled. Epoch:  67
# Performance on training data: Loss = 1.0054060220718384: Accuracy = 0.4866666793823242
# Performance on test set: : Loss = 1.0976535081863403: Accuracy = 0.6556375414085318
#
# Data shuffled. Epoch:  68
# Performance on training data: Loss = 0.9843534231185913: Accuracy = 0.5133333206176758
# Performance on test set: : Loss = 1.1541434526443481: Accuracy = 0.6561345990350099
#
# Data shuffled. Epoch:  69
# Performance on training data: Loss = 0.9557613134384155: Accuracy = 0.5266666412353516
# Performance on test set: : Loss = 1.1797477006912231: Accuracy = 0.6536231733419987
#
# Data shuffled. Epoch:  70
# Performance on training data: Loss = 0.9456729888916016: Accuracy = 0.6066666841506958
# Performance on test set: : Loss = 1.1233906745910645: Accuracy = 0.6534022171534977
#
# Data shuffled. Epoch:  71
# Performance on training data: Loss = 0.9494256377220154: Accuracy = 0.5666666626930237
# Performance on test set: : Loss = 1.1046502590179443: Accuracy = 0.6540346454448601
#
# Data shuffled. Epoch:  72
# Performance on training data: Loss = 0.9680036306381226: Accuracy = 0.54666668176651
# Performance on test set: : Loss = 1.1507103443145752: Accuracy = 0.6510160340186836
#
# Data shuffled. Epoch:  73
# Performance on training data: Loss = 0.9679359793663025: Accuracy = 0.5199999809265137
# Performance on test set: : Loss = 1.0860450267791748: Accuracy = 0.6504380834271508
#
# Data shuffled. Epoch:  74
# Performance on training data: Loss = 0.9775953888893127: Accuracy = 0.5400000214576721
# Performance on test set: : Loss = 1.0782197713851929: Accuracy = 0.6511722732745817
#
# Data shuffled. Epoch:  75
# Performance on training data: Loss = 0.9324126243591309: Accuracy = 0.5799999833106995
# Performance on test set: : Loss = 1.1907055377960205: Accuracy = 0.6509484711043301
#
# Data shuffled. Epoch:  76
# Performance on training data: Loss = 0.981876015663147: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.1418404579162598: Accuracy = 0.6497207235268393
#
# Data shuffled. Epoch:  77
# Performance on training data: Loss = 0.9493343830108643: Accuracy = 0.5199999809265137
# Performance on test set: : Loss = 1.108304738998413: Accuracy = 0.6502809239749865
#
# Data shuffled. Epoch:  78
# Performance on training data: Loss = 0.9681416749954224: Accuracy = 0.5533333420753479
# Performance on test set: : Loss = 1.0834311246871948: Accuracy = 0.6501831906388823
#
# Data shuffled. Epoch:  79
# Performance on training data: Loss = 0.9470226168632507: Accuracy = 0.5600000023841858
# Performance on test set: : Loss = 1.1255356073379517: Accuracy = 0.6494028529086546
#
# Data shuffled. Epoch:  80
# Performance on training data: Loss = 0.9529461860656738: Accuracy = 0.5266666412353516
# Performance on test set: : Loss = 1.1330077648162842: Accuracy = 0.6486226418699821
#
# Data shuffled. Epoch:  81
# Performance on training data: Loss = 0.9693579077720642: Accuracy = 0.5199999809265137
# Performance on test set: : Loss = 1.114395022392273: Accuracy = 0.6489959382469563
#
# Data shuffled. Epoch:  82
# Performance on training data: Loss = 0.9341446161270142: Accuracy = 0.5533333420753479
# Performance on test set: : Loss = 1.1069252490997314: Accuracy = 0.6496092668538413
#
# Data shuffled. Epoch:  83
# Performance on training data: Loss = 0.9533724784851074: Accuracy = 0.47333332896232605
# Performance on test set: : Loss = 1.1435991525650024: Accuracy = 0.6496201377187678
#
# Data shuffled. Epoch:  84
# Performance on training data: Loss = 0.9767041206359863: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.126860499382019: Accuracy = 0.6495940653181594
#
# Data shuffled. Epoch:  85
# Performance on training data: Loss = 0.9673484563827515: Accuracy = 0.5
# Performance on test set: : Loss = 1.1403377056121826: Accuracy = 0.6504195825916678
#
# Data shuffled. Epoch:  86
# Performance on training data: Loss = 0.9707526564598083: Accuracy = 0.5533333420753479
# Performance on test set: : Loss = 1.1218775510787964: Accuracy = 0.6504582949825124
#
# Data shuffled. Epoch:  87
# Performance on training data: Loss = 1.017128586769104: Accuracy = 0.5
# Performance on test set: : Loss = 1.1406477689743042: Accuracy = 0.6500249097582809
#
# Data shuffled. Epoch:  88
# Performance on training data: Loss = 0.9554279446601868: Accuracy = 0.5333333611488342
# Performance on test set: : Loss = 1.1009851694107056: Accuracy = 0.6502506151963817
#
# Data shuffled. Epoch:  89
# Performance on training data: Loss = 0.9498092532157898: Accuracy = 0.5799999833106995
# Performance on test set: : Loss = 1.1675783395767212: Accuracy = 0.6505789114884759
#
# Data shuffled. Epoch:  90
# Performance on training data: Loss = 0.9452863335609436: Accuracy = 0.5400000214576721
# Performance on test set: : Loss = 1.1204947233200073: Accuracy = 0.6513224196917694
#
# Data shuffled. Epoch:  91
# Performance on training data: Loss = 0.958513617515564: Accuracy = 0.5533333420753479
# Performance on test set: : Loss = 1.1420882940292358: Accuracy = 0.6514870789649706
#
# Data shuffled. Epoch:  92
# Performance on training data: Loss = 0.9565714597702026: Accuracy = 0.5066666603088379
# Performance on test set: : Loss = 1.0766750574111938: Accuracy = 0.6523892280927284
#
# Data shuffled. Epoch:  93
# Performance on training data: Loss = 0.959157407283783: Accuracy = 0.4866666793823242
# Performance on test set: : Loss = 1.1058242321014404: Accuracy = 0.6537131232224187
#
# Data shuffled. Epoch:  94
# Performance on training data: Loss = 0.9369109272956848: Accuracy = 0.5400000214576721
# Performance on test set: : Loss = 1.101499319076538: Accuracy = 0.6541297143577715
#
# Data shuffled. Epoch:  95
# Performance on training data: Loss = 0.8654192090034485: Accuracy = 0.6399999856948853
# Performance on test set: : Loss = 1.1276580095291138: Accuracy = 0.6548583115705618
#
# Data shuffled. Epoch:  96
# Performance on training data: Loss = 0.9177122712135315: Accuracy = 0.5866666436195374
# Performance on test set: : Loss = 1.0793007612228394: Accuracy = 0.6541341963811614
#
# Data shuffled. Epoch:  97
# Performance on training data: Loss = 0.8796431422233582: Accuracy = 0.653333306312561
# Performance on test set: : Loss = 1.141076922416687: Accuracy = 0.6526743817620843
#
# Data shuffled. Epoch:  98
# Performance on training data: Loss = 0.8850374221801758: Accuracy = 0.6000000238418579
# Performance on test set: : Loss = 1.1831774711608887: Accuracy = 0.6514151333939278
#
# Data shuffled. Epoch:  99
# Performance on training data: Loss = 0.9311841726303101: Accuracy = 0.5733333230018616
# Performance on test set: : Loss = 1.104659914970398: Accuracy = 0.6511541440219007
#
# Data shuffled. Epoch:  100
# Performance on training data: Loss = 0.8687595725059509: Accuracy = 0.6666666865348816
# Performance on test set: : Loss = 1.205507516860962: Accuracy = 0.6498240626533205
#
# Data shuffled. Epoch:  101
# Performance on training data: Loss = 0.9158557057380676: Accuracy = 0.6200000047683716
# Performance on test set: : Loss = 1.1033350229263306: Accuracy = 0.6497112887325468
#
# Data shuffled. Epoch:  102
# Performance on training data: Loss = 0.8757274150848389: Accuracy = 0.6666666865348816
# Performance on test set: : Loss = 1.192089319229126: Accuracy = 0.6495123171728434
#
# Data shuffled. Epoch:  103
# Performance on training data: Loss = 0.8703570365905762: Accuracy = 0.6600000262260437
# Performance on test set: : Loss = 1.276904582977295: Accuracy = 0.6477198917630312
#
# Data shuffled. Epoch:  104
# Performance on training data: Loss = 0.8703150153160095: Accuracy = 0.6266666650772095
# Performance on test set: : Loss = 1.1885197162628174: Accuracy = 0.6461732386340739
#
# Data shuffled. Epoch:  105
# Performance on training data: Loss = 0.9056026339530945: Accuracy = 0.6066666841506958
# Performance on test set: : Loss = 1.1436402797698975: Accuracy = 0.6449516668711575
#
# Data shuffled. Epoch:  106
# Performance on training data: Loss = 0.9260397553443909: Accuracy = 0.6066666841506958
# Performance on test set: : Loss = 1.0970344543457031: Accuracy = 0.6439053754366093
#
# Data shuffled. Epoch:  107
# Performance on training data: Loss = 0.8668007254600525: Accuracy = 0.6733333468437195
# Performance on test set: : Loss = 1.2958630323410034: Accuracy = 0.6426020097826135
#
# Data shuffled. Epoch:  108
# Performance on training data: Loss = 0.8800734281539917: Accuracy = 0.6333333253860474
# Performance on test set: : Loss = 1.2108687162399292: Accuracy = 0.6416865266879501
#
# Data shuffled. Epoch:  109
# Performance on training data: Loss = 0.8387638926506042: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.2150641679763794: Accuracy = 0.640726263528926
#
# Data shuffled. Epoch:  110
# Performance on training data: Loss = 0.8451223969459534: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.1479096412658691: Accuracy = 0.6398908218065891
#
# Data shuffled. Epoch:  111
# Performance on training data: Loss = 0.8523603081703186: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.0887863636016846: Accuracy = 0.6395341850208198
#
# Data shuffled. Epoch:  112
# Performance on training data: Loss = 0.8660567998886108: Accuracy = 0.6666666865348816
# Performance on test set: : Loss = 1.1204909086227417: Accuracy = 0.6387007972729742
#
# Data shuffled. Epoch:  113
# Performance on training data: Loss = 0.8515503406524658: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.17781400680542: Accuracy = 0.6381623137506961
#
# Data shuffled. Epoch:  114
# Performance on training data: Loss = 0.8679384589195251: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.190623164176941: Accuracy = 0.6367183406587484
#
# Data shuffled. Epoch:  115
# Performance on training data: Loss = 0.8625802397727966: Accuracy = 0.6800000071525574
# Performance on test set: : Loss = 1.234412670135498: Accuracy = 0.6367219165777803
#
# Data shuffled. Epoch:  116
# Performance on training data: Loss = 0.8781683444976807: Accuracy = 0.6600000262260437
# Performance on test set: : Loss = 1.1479213237762451: Accuracy = 0.635756164250067
#
# Data shuffled. Epoch:  117
# Performance on training data: Loss = 0.8116949200630188: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.1253465414047241: Accuracy = 0.6354588732328611
#
# Data shuffled. Epoch:  118
# Performance on training data: Loss = 0.846187174320221: Accuracy = 0.7066666483879089
# Performance on test set: : Loss = 1.2409601211547852: Accuracy = 0.635090958566785
#
# Data shuffled. Epoch:  119
# Performance on training data: Loss = 0.8817192316055298: Accuracy = 0.6466666460037231
# Performance on test set: : Loss = 1.1393221616744995: Accuracy = 0.6354199480528442
#
# Data shuffled. Epoch:  120
# Performance on training data: Loss = 0.8525334596633911: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.1227092742919922: Accuracy = 0.6342503742254159
#
# Data shuffled. Epoch:  121
# Performance on training data: Loss = 0.8679407835006714: Accuracy = 0.6600000262260437
# Performance on test set: : Loss = 1.209776759147644: Accuracy = 0.6345529033038139
#
# Data shuffled. Epoch:  122
# Performance on training data: Loss = 0.825534999370575: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.0946396589279175: Accuracy = 0.6340004421377784
#
# Data shuffled. Epoch:  123
# Performance on training data: Loss = 0.8182345628738403: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0896003246307373: Accuracy = 0.6333830482016367
#
# Data shuffled. Epoch:  124
# Performance on training data: Loss = 0.835999608039856: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.0364452600479126: Accuracy = 0.6335854687428614
#
# Data shuffled. Epoch:  125
# Performance on training data: Loss = 0.8095361590385437: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.1362370252609253: Accuracy = 0.6340396474169376
#
# Data shuffled. Epoch:  126
# Performance on training data: Loss = 0.8138860464096069: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.0930652618408203: Accuracy = 0.6342975617928065
#
# Data shuffled. Epoch:  127
# Performance on training data: Loss = 0.767192006111145: Accuracy = 0.8066666722297668
# Performance on test set: : Loss = 1.097905158996582: Accuracy = 0.6343198811736748
#
# Data shuffled. Epoch:  128
# Performance on training data: Loss = 0.854412853717804: Accuracy = 0.6800000071525574
# Performance on test set: : Loss = 1.1080186367034912: Accuracy = 0.6346186877281125
#
# Data shuffled. Epoch:  129
# Performance on training data: Loss = 0.8844563961029053: Accuracy = 0.653333306312561
# Performance on test set: : Loss = 1.086822509765625: Accuracy = 0.6350000440880793
#
# Data shuffled. Epoch:  130
# Performance on training data: Loss = 0.8064348101615906: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.1878381967544556: Accuracy = 0.6347389401831955
#
# Data shuffled. Epoch:  131
# Performance on training data: Loss = 0.8270367383956909: Accuracy = 0.7066666483879089
# Performance on test set: : Loss = 1.1441131830215454: Accuracy = 0.6351633580667514
#
# Data shuffled. Epoch:  132
# Performance on training data: Loss = 0.8084617853164673: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0411529541015625: Accuracy = 0.635482537501324
#
# Data shuffled. Epoch:  133
# Performance on training data: Loss = 0.8364096283912659: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.117849349975586: Accuracy = 0.6354229406805647
#
# Data shuffled. Epoch:  134
# Performance on training data: Loss = 0.8771084547042847: Accuracy = 0.6600000262260437
# Performance on test set: : Loss = 1.2325209379196167: Accuracy = 0.6358723710772902
#
# Data shuffled. Epoch:  135
# Performance on training data: Loss = 0.8098214268684387: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.0723605155944824: Accuracy = 0.6360986847976748
#
# Data shuffled. Epoch:  136
# Performance on training data: Loss = 0.8781940937042236: Accuracy = 0.653333306312561
# Performance on test set: : Loss = 1.1483346223831177: Accuracy = 0.6359178824669132
#
# Data shuffled. Epoch:  137
# Performance on training data: Loss = 0.8150184750556946: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.1357449293136597: Accuracy = 0.6362352660076863
#
# Data shuffled. Epoch:  138
# Performance on training data: Loss = 0.892406702041626: Accuracy = 0.6399999856948853
# Performance on test set: : Loss = 1.1558572053909302: Accuracy = 0.6361456720968538
#
# Data shuffled. Epoch:  139
# Performance on training data: Loss = 0.7592290639877319: Accuracy = 0.8066666722297668
# Performance on test set: : Loss = 1.1246342658996582: Accuracy = 0.6366275397602343
#
# Data shuffled. Epoch:  140
# Performance on training data: Loss = 0.8426435589790344: Accuracy = 0.6666666865348816
# Performance on test set: : Loss = 1.0591742992401123: Accuracy = 0.6370373553257165
#
# Data shuffled. Epoch:  141
# Performance on training data: Loss = 0.7897200584411621: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.0491719245910645: Accuracy = 0.6370470200938934
#
# Data shuffled. Epoch:  142
# Performance on training data: Loss = 0.8309303522109985: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.1124920845031738: Accuracy = 0.637713694694961
#
# Data shuffled. Epoch:  143
# Performance on training data: Loss = 0.8394433856010437: Accuracy = 0.7066666483879089
# Performance on test set: : Loss = 1.0904728174209595: Accuracy = 0.6382474594578248
#
# Data shuffled. Epoch:  144
# Performance on training data: Loss = 0.8472437858581543: Accuracy = 0.7066666483879089
# Performance on test set: : Loss = 1.0361133813858032: Accuracy = 0.6384535246541035
#
# Data shuffled. Epoch:  145
# Performance on training data: Loss = 0.8127335906028748: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0962681770324707: Accuracy = 0.6392079703832144
#
# Data shuffled. Epoch:  146
# Performance on training data: Loss = 0.834513783454895: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.1499900817871094: Accuracy = 0.6395614867753898
#
# Data shuffled. Epoch:  147
# Performance on training data: Loss = 0.7973736524581909: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.0769540071487427: Accuracy = 0.6401020988009977
#
# Data shuffled. Epoch:  148
# Performance on training data: Loss = 0.8565723896026611: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.1262365579605103: Accuracy = 0.64070467044387
#
# Data shuffled. Epoch:  149
# Performance on training data: Loss = 0.7833957672119141: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.105739712715149: Accuracy = 0.6413320681990734
#
# Data shuffled. Epoch:  150
# Performance on training data: Loss = 0.7958788275718689: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.0879974365234375: Accuracy = 0.6418428799961975
#
# Data shuffled. Epoch:  151
# Performance on training data: Loss = 0.8438541293144226: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.053834080696106: Accuracy = 0.6424496635113777
#
# Data shuffled. Epoch:  152
# Performance on training data: Loss = 0.828156054019928: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.1049023866653442: Accuracy = 0.642983794788417
#
# Data shuffled. Epoch:  153
# Performance on training data: Loss = 0.8253888487815857: Accuracy = 0.7066666483879089
# Performance on test set: : Loss = 1.1200467348098755: Accuracy = 0.6435164916164036
#
# Data shuffled. Epoch:  154
# Performance on training data: Loss = 0.7928021550178528: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.1102924346923828: Accuracy = 0.6440681745404576
#
# Data shuffled. Epoch:  155
# Performance on training data: Loss = 0.8213407397270203: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.0846142768859863: Accuracy = 0.6446553854083779
#
# Data shuffled. Epoch:  156
# Performance on training data: Loss = 0.8117954730987549: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.1016989946365356: Accuracy = 0.6450577222506662
#
# Data shuffled. Epoch:  157
# Performance on training data: Loss = 0.8110454082489014: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.1280161142349243: Accuracy = 0.6456236423729989
#
# Data shuffled. Epoch:  158
# Performance on training data: Loss = 0.776676595211029: Accuracy = 0.7799999713897705
# Performance on test set: : Loss = 1.0822608470916748: Accuracy = 0.6455500839420432
#
# Data shuffled. Epoch:  159
# Performance on training data: Loss = 0.7805459499359131: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.1418144702911377: Accuracy = 0.6459314544998266
#
# Data shuffled. Epoch:  160
# Performance on training data: Loss = 0.8088367581367493: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.0892425775527954: Accuracy = 0.6463838078145149
#
# Data shuffled. Epoch:  161
# Performance on training data: Loss = 0.7938553690910339: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.125386357307434: Accuracy = 0.6469590206490414
#
# Data shuffled. Epoch:  162
# Performance on training data: Loss = 0.794373095035553: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.0676065683364868: Accuracy = 0.647393912959265
#
# Data shuffled. Epoch:  163
# Performance on training data: Loss = 0.8377507328987122: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.059935212135315: Accuracy = 0.6478256473682816
#
# Data shuffled. Epoch:  164
# Performance on training data: Loss = 0.8200356364250183: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0317730903625488: Accuracy = 0.6484241352142005
#
# Data shuffled. Epoch:  165
# Performance on training data: Loss = 0.8021023273468018: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 0.9908060431480408: Accuracy = 0.6492489709082023
#
# Data shuffled. Epoch:  166
# Performance on training data: Loss = 0.8630247712135315: Accuracy = 0.6800000071525574
# Performance on test set: : Loss = 1.0429975986480713: Accuracy = 0.6500100813319131
#
# Data shuffled. Epoch:  167
# Performance on training data: Loss = 0.8173506259918213: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0513465404510498: Accuracy = 0.6505264077929279
#
# Data shuffled. Epoch:  168
# Performance on training data: Loss = 0.7826290130615234: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0716317892074585: Accuracy = 0.6511539622915754
#
# Data shuffled. Epoch:  169
# Performance on training data: Loss = 0.7746855616569519: Accuracy = 0.7799999713897705
# Performance on test set: : Loss = 1.0770682096481323: Accuracy = 0.6516443004705553
#
# Data shuffled. Epoch:  170
# Performance on training data: Loss = 0.7750763297080994: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0803791284561157: Accuracy = 0.6519650540848793
#
# Data shuffled. Epoch:  171
# Performance on training data: Loss = 0.7871248126029968: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.127427577972412: Accuracy = 0.6524061381563897
#
# Data shuffled. Epoch:  172
# Performance on training data: Loss = 0.8066207766532898: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 0.9824308753013611: Accuracy = 0.6530038320303116
#
# Data shuffled. Epoch:  173
# Performance on training data: Loss = 0.7803508043289185: Accuracy = 0.7866666913032532
# Performance on test set: : Loss = 1.0286093950271606: Accuracy = 0.6535872445906036
#
# Data shuffled. Epoch:  174
# Performance on training data: Loss = 0.788492739200592: Accuracy = 0.7666666507720947
# Performance on test set: : Loss = 1.17719566822052: Accuracy = 0.6539302317017994
#
# Data shuffled. Epoch:  175
# Performance on training data: Loss = 0.7759702801704407: Accuracy = 0.7666666507720947
# Performance on test set: : Loss = 1.1448686122894287: Accuracy = 0.6541748249518248
#
# Data shuffled. Epoch:  176
# Performance on training data: Loss = 0.8163719177246094: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0044317245483398: Accuracy = 0.6546656370245796
#
# Data shuffled. Epoch:  177
# Performance on training data: Loss = 0.8837339282035828: Accuracy = 0.653333306312561
# Performance on test set: : Loss = 1.1119194030761719: Accuracy = 0.6549850793099309
#
# Data shuffled. Epoch:  178
# Performance on training data: Loss = 0.8503527641296387: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.0733503103256226: Accuracy = 0.6554676438895533
#
# Data shuffled. Epoch:  179
# Performance on training data: Loss = 0.7988041043281555: Accuracy = 0.746666669845581
# Performance on test set: : Loss = 1.04608154296875: Accuracy = 0.6559374771126636
#
# Data shuffled. Epoch:  180
# Performance on training data: Loss = 0.7870597839355469: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0967656373977661: Accuracy = 0.656622272490437
#
# Data shuffled. Epoch:  181
# Performance on training data: Loss = 0.8583941459655762: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.1002709865570068: Accuracy = 0.6566546449306612
#
# Data shuffled. Epoch:  182
# Performance on training data: Loss = 0.8201246857643127: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.04689621925354: Accuracy = 0.6567822220479799
#
# Data shuffled. Epoch:  183
# Performance on training data: Loss = 0.7669908404350281: Accuracy = 0.7933333516120911
# Performance on test set: : Loss = 1.15488600730896: Accuracy = 0.6572683926479376
#
# Data shuffled. Epoch:  184
# Performance on training data: Loss = 0.7738333344459534: Accuracy = 0.7799999713897705
# Performance on test set: : Loss = 1.025840401649475: Accuracy = 0.657760531447544
#
# Data shuffled. Epoch:  185
# Performance on training data: Loss = 0.7563114762306213: Accuracy = 0.7933333516120911
# Performance on test set: : Loss = 0.980006217956543: Accuracy = 0.6574023704325871
#
# Data shuffled. Epoch:  186
# Performance on training data: Loss = 0.8186776041984558: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.091611623764038: Accuracy = 0.6577787920453633
#
# Data shuffled. Epoch:  187
# Performance on training data: Loss = 0.8314085006713867: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.0376445055007935: Accuracy = 0.6578883973534821
#
# Data shuffled. Epoch:  188
# Performance on training data: Loss = 0.7963663935661316: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.0638607740402222: Accuracy = 0.6583976310555508
#
# Data shuffled. Epoch:  189
# Performance on training data: Loss = 0.7556161880493164: Accuracy = 0.8066666722297668
# Performance on test set: : Loss = 1.0871083736419678: Accuracy = 0.6586754610919976
#
# Data shuffled. Epoch:  190
# Performance on training data: Loss = 0.7794808745384216: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0812592506408691: Accuracy = 0.6585524428245734
#
# Data shuffled. Epoch:  191
# Performance on training data: Loss = 0.8174558281898499: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0387108325958252: Accuracy = 0.6589743675554219
#
# Data shuffled. Epoch:  192
# Performance on training data: Loss = 0.8192121982574463: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0226179361343384: Accuracy = 0.6593212130833033
#
# Data shuffled. Epoch:  193
# Performance on training data: Loss = 0.7845486998558044: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.0686432123184204: Accuracy = 0.6593985069787585
#
# Data shuffled. Epoch:  194
# Performance on training data: Loss = 0.7666382193565369: Accuracy = 0.7866666913032532
# Performance on test set: : Loss = 1.0963307619094849: Accuracy = 0.6595574440705169
#
# Data shuffled. Epoch:  195
# Performance on training data: Loss = 0.7838433980941772: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0975674390792847: Accuracy = 0.659661906592236
#
# Data shuffled. Epoch:  196
# Performance on training data: Loss = 0.8269360065460205: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.1502450704574585: Accuracy = 0.6600298909117179
#
# Data shuffled. Epoch:  197
# Performance on training data: Loss = 0.782265841960907: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.0850423574447632: Accuracy = 0.6604787040690243
#
# Data shuffled. Epoch:  198
# Performance on training data: Loss = 0.8340682983398438: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 0.9888562560081482: Accuracy = 0.6606830355636574
#
# Data shuffled. Epoch:  199
# Performance on training data: Loss = 0.8214612007141113: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.080549716949463: Accuracy = 0.6610147055826678
#
# Data shuffled. Epoch:  200
# Performance on training data: Loss = 0.8242193460464478: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.1030656099319458: Accuracy = 0.6611592211998396
#
# Data shuffled. Epoch:  201
# Performance on training data: Loss = 0.8598154783248901: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.0589708089828491: Accuracy = 0.6608704388865795
#
# Data shuffled. Epoch:  202
# Performance on training data: Loss = 0.8561080694198608: Accuracy = 0.6666666865348816
# Performance on test set: : Loss = 1.078465461730957: Accuracy = 0.6613014916333066
#
# Data shuffled. Epoch:  203
# Performance on training data: Loss = 0.8309627175331116: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.0564136505126953: Accuracy = 0.661546774140652
#
# Data shuffled. Epoch:  204
# Performance on training data: Loss = 0.8274122476577759: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.051934003829956: Accuracy = 0.6619583709334881
#
# Data shuffled. Epoch:  205
# Performance on training data: Loss = 0.7930004596710205: Accuracy = 0.7666666507720947
# Performance on test set: : Loss = 1.0133360624313354: Accuracy = 0.6623659509585589
#
# Data shuffled. Epoch:  206
# Performance on training data: Loss = 0.8039475679397583: Accuracy = 0.753333330154419
# Performance on test set: : Loss = 1.133521556854248: Accuracy = 0.6625221968138789
#
# Data shuffled. Epoch:  207
# Performance on training data: Loss = 0.8021637797355652: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0679513216018677: Accuracy = 0.662827729838028
#
# Data shuffled. Epoch:  208
# Performance on training data: Loss = 0.8125993609428406: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0928412675857544: Accuracy = 0.6625879350288753
#
# Data shuffled. Epoch:  209
# Performance on training data: Loss = 0.7559881210327148: Accuracy = 0.7866666913032532
# Performance on test set: : Loss = 1.128490686416626: Accuracy = 0.6628475710748065
#
# Data shuffled. Epoch:  210
# Performance on training data: Loss = 0.811307966709137: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.1791764497756958: Accuracy = 0.6629989028443697
#
# Data shuffled. Epoch:  211
# Performance on training data: Loss = 0.7647203803062439: Accuracy = 0.7799999713897705
# Performance on test set: : Loss = 1.058008074760437: Accuracy = 0.6630008749173809
#
# Data shuffled. Epoch:  212
# Performance on training data: Loss = 0.8707322478294373: Accuracy = 0.6733333468437195
# Performance on test set: : Loss = 1.0265045166015625: Accuracy = 0.6634846884140776
#
# Data shuffled. Epoch:  213
# Performance on training data: Loss = 0.8183446526527405: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.103335976600647: Accuracy = 0.6638591496031773
#
# Data shuffled. Epoch:  214
# Performance on training data: Loss = 0.7470331788063049: Accuracy = 0.8133333325386047
# Performance on test set: : Loss = 1.0274184942245483: Accuracy = 0.6643334586435808
#
# Data shuffled. Epoch:  215
# Performance on training data: Loss = 0.808017373085022: Accuracy = 0.746666669845581
# Performance on test set: : Loss = 1.0486910343170166: Accuracy = 0.6646687819368766
#
# Data shuffled. Epoch:  216
# Performance on training data: Loss = 0.8064756989479065: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0814509391784668: Accuracy = 0.6648469027959297
#
# Data shuffled. Epoch:  217
# Performance on training data: Loss = 0.7687804698944092: Accuracy = 0.7866666913032532
# Performance on test set: : Loss = 1.0629920959472656: Accuracy = 0.665008513942017
#
# Data shuffled. Epoch:  218
# Performance on training data: Loss = 0.7362483143806458: Accuracy = 0.8133333325386047
# Performance on test set: : Loss = 1.1066111326217651: Accuracy = 0.6650110450461852
#
# Data shuffled. Epoch:  219
# Performance on training data: Loss = 0.8181530237197876: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.0301405191421509: Accuracy = 0.6653124101310776
#
# Data shuffled. Epoch:  220
# Performance on training data: Loss = 0.8139118552207947: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.0718971490859985: Accuracy = 0.6655397538793097
#
# Data shuffled. Epoch:  221
# Performance on training data: Loss = 0.8390416502952576: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.0980714559555054: Accuracy = 0.6654190871205756
#
# Data shuffled. Epoch:  222
# Performance on training data: Loss = 0.7427234053611755: Accuracy = 0.8066666722297668
# Performance on test set: : Loss = 1.060804843902588: Accuracy = 0.6657342785066891
#
# Data shuffled. Epoch:  223
# Performance on training data: Loss = 0.8272116780281067: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.0524652004241943: Accuracy = 0.6659718165499031
#
# Data shuffled. Epoch:  224
# Performance on training data: Loss = 0.8013768196105957: Accuracy = 0.746666669845581
# Performance on test set: : Loss = 1.1007943153381348: Accuracy = 0.6661923530711193
#
# Data shuffled. Epoch:  225
# Performance on training data: Loss = 0.7977810502052307: Accuracy = 0.746666669845581
# Performance on test set: : Loss = 1.0573923587799072: Accuracy = 0.6661796836974261
#
# Data shuffled. Epoch:  226
# Performance on training data: Loss = 0.8584872484207153: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.0303231477737427: Accuracy = 0.6664364983687878
#
# Data shuffled. Epoch:  227
# Performance on training data: Loss = 0.8591644167900085: Accuracy = 0.6866666674613953
# Performance on test set: : Loss = 1.069602608680725: Accuracy = 0.66650571019142
#
# Data shuffled. Epoch:  228
# Performance on training data: Loss = 0.8441484570503235: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.050418734550476: Accuracy = 0.6667394955834656
#
# Data shuffled. Epoch:  229
# Performance on training data: Loss = 0.8120825290679932: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.1310807466506958: Accuracy = 0.6668842122254347
#
# Data shuffled. Epoch:  230
# Performance on training data: Loss = 0.860579252243042: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.1007105112075806: Accuracy = 0.6668111170285702
#
# Data shuffled. Epoch:  231
# Performance on training data: Loss = 0.8325151205062866: Accuracy = 0.7200000286102295
# Performance on test set: : Loss = 1.1021952629089355: Accuracy = 0.6669733107082816
#
# Data shuffled. Epoch:  232
# Performance on training data: Loss = 0.8497315049171448: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.1486434936523438: Accuracy = 0.6668527302454108
#
# Data shuffled. Epoch:  233
# Performance on training data: Loss = 0.8552640676498413: Accuracy = 0.699999988079071
# Performance on test set: : Loss = 1.1305530071258545: Accuracy = 0.6667379760032311
#
# Data shuffled. Epoch:  234
# Performance on training data: Loss = 0.7886208295822144: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.0794180631637573: Accuracy = 0.6668228687334145
#
# Data shuffled. Epoch:  235
# Performance on training data: Loss = 0.8047226071357727: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0576801300048828: Accuracy = 0.6669446957221775
#
# Data shuffled. Epoch:  236
# Performance on training data: Loss = 0.7410054802894592: Accuracy = 0.8133333325386047
# Performance on test set: : Loss = 1.0994343757629395: Accuracy = 0.6673141340128339
#
# Data shuffled. Epoch:  237
# Performance on training data: Loss = 0.7632445693016052: Accuracy = 0.7866666913032532
# Performance on test set: : Loss = 1.1664607524871826: Accuracy = 0.6675119807646991
#
# Data shuffled. Epoch:  238
# Performance on training data: Loss = 0.8109641671180725: Accuracy = 0.7333333492279053
# Performance on test set: : Loss = 1.1575324535369873: Accuracy = 0.6676893139886442
#
# Data shuffled. Epoch:  239
# Performance on training data: Loss = 0.7658736109733582: Accuracy = 0.7733333110809326
# Performance on test set: : Loss = 1.1232006549835205: Accuracy = 0.6678603908129069
#
# Data shuffled. Epoch:  240
# Performance on training data: Loss = 0.7911236882209778: Accuracy = 0.7599999904632568
# Performance on test set: : Loss = 1.1907926797866821: Accuracy = 0.6677587262788666
#
# Data shuffled. Epoch:  241
# Performance on training data: Loss = 0.7668213844299316: Accuracy = 0.7933333516120911
# Performance on test set: : Loss = 1.1858680248260498: Accuracy = 0.6676942000625063
#
# Data shuffled. Epoch:  242
# Performance on training data: Loss = 0.8391154408454895: Accuracy = 0.6933333277702332
# Performance on test set: : Loss = 1.1431286334991455: Accuracy = 0.6674660627625132
#
# Data shuffled. Epoch:  243
# Performance on training data: Loss = 0.7897380590438843: Accuracy = 0.746666669845581
# Performance on test set: : Loss = 1.1151814460754395: Accuracy = 0.667680709482112
#
# Data shuffled. Epoch:  244
# Performance on training data: Loss = 0.8076039552688599: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.1388388872146606: Accuracy = 0.6678301846545396
#
# Data shuffled. Epoch:  245
# Performance on training data: Loss = 0.897733747959137: Accuracy = 0.6399999856948853
# Performance on test set: : Loss = 1.0447757244110107: Accuracy = 0.6680733117270463
#
# Data shuffled. Epoch:  246
# Performance on training data: Loss = 0.8221437335014343: Accuracy = 0.7266666889190674
# Performance on test set: : Loss = 1.0237293243408203: Accuracy = 0.6683863606367914
#
# Data shuffled. Epoch:  247
# Performance on training data: Loss = 0.836704671382904: Accuracy = 0.7133333086967468
# Performance on test set: : Loss = 1.073907494544983: Accuracy = 0.668736807138288
#
# Data shuffled. Epoch:  248
# Performance on training data: Loss = 0.8623864650726318: Accuracy = 0.6733333468437195
# Performance on test set: : Loss = 1.1096256971359253: Accuracy = 0.6690129545346217
#
# Data shuffled. Epoch:  249
# Performance on training data: Loss = 0.8017710447311401: Accuracy = 0.7400000095367432
# Performance on test set: : Loss = 1.0980098247528076: Accuracy = 0.6689195595134924
#
# Optimisation finished!

# %%
# %run trainRNN_plot_utils.py
plot_one_input(F1_scores, trainLosses, testLosses, n_epoch)

# %%
# SAVE DATA
# Save the created samples, such tha the NNs can load them easily

# Save data into Python file
import pickle
with open('resultsStatic_ANM_HBTRC.pickle', 'wb') as f:
    pickle.dump( trainLosses, f, pickle.HIGHEST_PROTOCOL )
    pickle.dump( testLosses, f, pickle.HIGHEST_PROTOCOL )
    pickle.dump( F1_scores, f, pickle.HIGHEST_PROTOCOL )
    pickle.dump( trainAccuracy, f, pickle.HIGHEST_PROTOCOL )
    print( 'Data saved into pickle.' )
# Out:
# Data saved into pickle.
